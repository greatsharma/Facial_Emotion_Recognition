# %%
import os
import cv2
import numpy as np
from collections import defaultdict

import scikitplot
import seaborn as sns
from matplotlib import pyplot

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import TimeDistributed, LSTM, Bidirectional
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
    print(f"{dir_} has {count} number of images")
# Out:
# fear has 75 number of images
# surprise has 249 number of images
# happy has 207 number of images
# sadness has 84 number of images
# anger has 135 number of images

# %% [markdown]
# `sadness` and `fear` has very low number of images as compared to other classes

# %%
TOP_EMOTIONS = ["happy", "surprise", "anger", "sadness", "fear"]

# %% [markdown]
# ### Data Preprocessing
#
# I first make the data compatible for neural nets

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

data = defaultdict(str)
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        data[dir_] = defaultdict(list)
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            sub = f.split("_")[0]
            data[dir_][sub].append(f)

# data

# %%
def preprocess_list(x):
    return int((x.split("_")[2]).split(".")[0])

def preprocess_dict(x):
    res = list(np.argsort(list(map(preprocess_list, x))))
    return [x[i] for i in res]

def img2array(x,path):
    arr = np.empty(shape=(3,48,48))
    for i,f in enumerate(x):
        img = cv2.imread(path+f, 0)
        arr[i] = img
    return arr

# %%
for emotion in data:
    data[emotion] = dict((k, preprocess_dict(v)) for k, v in data[emotion].items())
    data[emotion] = dict((k, img2array(v, path=INPUT_PATH + emotion + "/")) for k, v in data[emotion].items())

# data

# %%
for k,v in data.items():
    print(f"{k} has {len(v)} samples")
# Out:
# fear has 25 samples
# surprise has 83 samples
# happy has 69 samples
# sadness has 28 samples
# anger has 45 samples

# %%
surprise = np.stack(data["surprise"].values(), axis=0)
surprise = surprise.reshape(*surprise.shape,1)

happy = np.stack(data["happy"].values(), axis=0)
happy = happy.reshape(*happy.shape,1)

anger = np.stack(data["anger"].values(), axis=0)
anger = anger.reshape(*anger.shape,1)

sadness = np.stack(data["sadness"].values(), axis=0)
sadness = sadness.reshape(*sadness.shape,1)

fear = np.stack(data["fear"].values(), axis=0)
fear = fear.reshape(*fear.shape,1)

X = np.concatenate((surprise, happy, anger, sadness, fear))
y = np.concatenate((np.array([0]*83), np.array([1]*69), np.array([2]*45), np.array([3]*28), np.array([4]*25)))
y = np_utils.to_categorical(y)

X.shape, y.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# ((250, 3, 48, 48, 1), (250, 5))

# %%
label_emotion_mapper = {0:"surprise", 1:"happy", 2:"anger", 3:"sadness", 4:"fear"}

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.7, stratify=y, shuffle=True, random_state=42)
X_train.shape, X_valid.shape
# Out:
# ((175, 3, 48, 48, 1), (75, 3, 48, 48, 1))

# %%
np.random.seed(42)
surprise_idx = np.random.choice(np.where(y_train[:, 0]==1)[0], size=1)
happy_idx = np.random.choice(np.where(y_train[:, 1]==1)[0], size=1)
anger_idx = np.random.choice(np.where(y_train[:, 2]==1)[0], size=1)
sad_idx = np.random.choice(np.where(y_train[:, 3]==1)[0], size=1)
fear_idx = np.random.choice(np.where(y_train[:, 4]==1)[0], size=1)

fig = pyplot.figure(1, (6,13))

i = 0
for name, idx in zip(label_emotion_mapper.values(), [surprise_idx, happy_idx, anger_idx, sad_idx, fear_idx]):
    for j in range(3):
        i += 1
        ax = pyplot.subplot(5,3,i)
        sample_img = X_train[idx][0,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(name)

# %%
# data normalization
X_train = X_train / 255.
X_valid = X_valid / 255.

# %%
def build_dcnn(input_shape, show_arch=True):
    """
    This is a Deep Convolutional Neural Network (DCNN). For generalization purpose I used dropouts in regular intervals.
    I used `ELU` as the activation because it avoids dying relu problem but also performed well as compared to LeakyRelu
    atleast in this case. `he_normal` kernel initializer is used as it suits ELU. BatchNormalization is also used for better
    results.
    """
    net = Sequential(name='DCNN')

    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            input_shape=input_shape,
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_1'
        )
    )
    net.add(BatchNormalization(name='batchnorm_1'))
    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_2'
        )
    )
    net.add(BatchNormalization(name='batchnorm_2'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
    net.add(Dropout(0.45, name='dropout_1'))

    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_3'
        )
    )
    net.add(BatchNormalization(name='batchnorm_3'))
    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_4'
        )
    )
    net.add(BatchNormalization(name='batchnorm_4'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
    net.add(Dropout(0.45, name='dropout_2'))

    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_5'
        )
    )
    net.add(BatchNormalization(name='batchnorm_5'))
    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_6'
        )
    )
    net.add(BatchNormalization(name='batchnorm_6'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
    net.add(Dropout(0.4, name='dropout_3'))

    net.add(
        Conv2D(
            filters=512,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_7'
        )
    )
    net.add(BatchNormalization(name='batchnorm_7'))
    net.add(
        Conv2D(
            filters=512,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_8'
        )
    )
    net.add(BatchNormalization(name='batchnorm_8'))
    
    net.add(Dropout(0.4, name='dropout_4'))
    
    net.add(GlobalMaxPool2D(name="globalmax2d"))
    
    if show_arch:
        net.summary()
    
    return net

# %%
def memory_model(input_shape, num_class, show_arch=True):
    dcnn = build_dcnn(input_shape[1:], show_arch=False)
    
    model = Sequential(name="convolutional_Bidrectional_LSTM")

    model.add(
        TimeDistributed(
            dcnn,
            input_shape=input_shape,
            name="time_distributed",
        )
    )
    
    model.add(Bidirectional(LSTM(128, return_sequences=True, name="bidirect_lstm_1")))
    model.add(Dropout(.35, name="dropout_1"))
    model.add(Bidirectional(LSTM(64, return_sequences=False, name="bidirect_lstm_2")))
    model.add(Dropout(.45, name="dropout_2"))

    model.add(
        Dense(
            128,
            activation='elu',
            kernel_initializer='he_normal',
            name='dense_1'
        )
    )
    model.add(BatchNormalization(name='batchnorm_1'))
    model.add(Dropout(.7, name="dropout_3"))

    model.add(
        Dense(
            num_class,
            activation='softmax',
            name='out_layer'
        )
    )
    
    if show_arch:
        model.summary()
    
    return model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00005,
    patience=12,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.8,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
#     early_stopping,
    lr_scheduler,
]

batch_size = 32
epochs = 100

# %%
INPUT_SHAPE = (3, 48, 48, 1)
optim = optimizers.Nadam(0.001)

model = memory_model(INPUT_SHAPE, num_class=5)
model.compile(
        loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy']
)
# Out:
# Model: "convolutional_Bidrectional_LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 3, 512)            4691904
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 3, 256)            656384
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 256)            0
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batchnorm_1 (BatchNormalizat (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 5)                 645
# =================================================================
# Total params: 5,530,309
# Trainable params: 5,526,213
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_valid, y_valid),
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Train on 175 samples, validate on 75 samples
# Epoch 1/100
# 175/175 [==============================] - 11s 61ms/sample - loss: 3.0899 - accuracy: 0.2514 - val_loss: 1.5466 - val_accuracy: 0.2800
# Epoch 2/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.1284 - accuracy: 0.2057 - val_loss: 1.5526 - val_accuracy: 0.2800
# Epoch 3/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.3546 - accuracy: 0.1486 - val_loss: 1.5648 - val_accuracy: 0.2800
# Epoch 4/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.2569 - accuracy: 0.2171 - val_loss: 1.5835 - val_accuracy: 0.2800
# Epoch 5/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.8025 - accuracy: 0.2629 - val_loss: 1.6560 - val_accuracy: 0.2800
# Epoch 6/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.9125 - accuracy: 0.2229 - val_loss: 1.6349 - val_accuracy: 0.2667
# Epoch 7/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.0617 - accuracy: 0.2000 - val_loss: 1.5904 - val_accuracy: 0.2800
# Epoch 8/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.0230 - accuracy: 0.2343 - val_loss: 1.6052 - val_accuracy: 0.2933
# Epoch 9/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.8249 - accuracy: 0.1657 - val_loss: 1.6252 - val_accuracy: 0.1867
# Epoch 10/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.5695 - accuracy: 0.2514 - val_loss: 1.6957 - val_accuracy: 0.1733
# Epoch 11/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6147 - accuracy: 0.2743 - val_loss: 1.6717 - val_accuracy: 0.1733
# Epoch 12/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.4802 - accuracy: 0.2971 - val_loss: 1.6849 - val_accuracy: 0.1733
# Epoch 13/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6741 - accuracy: 0.2000 - val_loss: 1.7013 - val_accuracy: 0.1733
# Epoch 14/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6696 - accuracy: 0.2057 - val_loss: 1.6756 - val_accuracy: 0.1733
# Epoch 15/100
# 160/175 [==========================>...] - ETA: 0s - loss: 2.6180 - accuracy: 0.2125
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6542 - accuracy: 0.1943 - val_loss: 1.7046 - val_accuracy: 0.1733
# Epoch 16/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.4678 - accuracy: 0.2571 - val_loss: 1.6822 - val_accuracy: 0.1733
# Epoch 17/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.4286 - accuracy: 0.2571 - val_loss: 1.6127 - val_accuracy: 0.1733
# Epoch 18/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.9341 - accuracy: 0.3600 - val_loss: 1.6076 - val_accuracy: 0.1733
# Epoch 19/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.3104 - accuracy: 0.2857 - val_loss: 1.6324 - val_accuracy: 0.1733
# Epoch 20/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.2915 - accuracy: 0.3543 - val_loss: 1.5541 - val_accuracy: 0.2400
# Epoch 21/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.1354 - accuracy: 0.3429 - val_loss: 1.5551 - val_accuracy: 0.3600
# Epoch 22/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.9973 - accuracy: 0.3829 - val_loss: 1.4836 - val_accuracy: 0.4400
# Epoch 23/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.8880 - accuracy: 0.4400 - val_loss: 1.3950 - val_accuracy: 0.4267
# Epoch 24/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.6336 - accuracy: 0.4743 - val_loss: 1.3369 - val_accuracy: 0.4667
# Epoch 25/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.5025 - accuracy: 0.4571 - val_loss: 1.1621 - val_accuracy: 0.5733
# Epoch 26/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.3710 - accuracy: 0.5486 - val_loss: 1.3397 - val_accuracy: 0.4267
# Epoch 27/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.6420 - accuracy: 0.4743 - val_loss: 1.2555 - val_accuracy: 0.5067
# Epoch 28/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.5694 - accuracy: 0.5143 - val_loss: 1.0824 - val_accuracy: 0.6133
# Epoch 29/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.3734 - accuracy: 0.5771 - val_loss: 1.3647 - val_accuracy: 0.4933
# Epoch 30/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.2490 - accuracy: 0.6114 - val_loss: 1.0125 - val_accuracy: 0.6400
# Epoch 31/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.1962 - accuracy: 0.5543 - val_loss: 0.9873 - val_accuracy: 0.6533
# Epoch 32/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0545 - accuracy: 0.6857 - val_loss: 0.8542 - val_accuracy: 0.6800
# Epoch 33/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.2180 - accuracy: 0.6286 - val_loss: 0.8591 - val_accuracy: 0.6933
# Epoch 34/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.1118 - accuracy: 0.6000 - val_loss: 0.8110 - val_accuracy: 0.6933
# Epoch 35/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0098 - accuracy: 0.6686 - val_loss: 0.8314 - val_accuracy: 0.7067
# Epoch 36/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0701 - accuracy: 0.6686 - val_loss: 0.7130 - val_accuracy: 0.7467
# Epoch 37/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9781 - accuracy: 0.6857 - val_loss: 0.7422 - val_accuracy: 0.7467
# Epoch 38/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.1614 - accuracy: 0.6114 - val_loss: 0.7344 - val_accuracy: 0.7200
# Epoch 39/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9251 - accuracy: 0.6686 - val_loss: 0.8369 - val_accuracy: 0.6667
# Epoch 40/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8961 - accuracy: 0.6800 - val_loss: 0.6310 - val_accuracy: 0.7600
# Epoch 41/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8196 - accuracy: 0.6914 - val_loss: 0.6290 - val_accuracy: 0.7600
# Epoch 42/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8955 - accuracy: 0.7029 - val_loss: 0.7575 - val_accuracy: 0.7200
# Epoch 43/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7971 - accuracy: 0.6857 - val_loss: 0.6945 - val_accuracy: 0.7467
# Epoch 44/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7803 - accuracy: 0.7257 - val_loss: 0.6484 - val_accuracy: 0.7333
# Epoch 45/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6530 - accuracy: 0.7829 - val_loss: 0.5960 - val_accuracy: 0.7467
# Epoch 46/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6682 - accuracy: 0.7600 - val_loss: 0.7006 - val_accuracy: 0.7467
# Epoch 47/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6834 - accuracy: 0.7200 - val_loss: 0.6124 - val_accuracy: 0.7733
# Epoch 48/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8766 - accuracy: 0.7371 - val_loss: 0.5475 - val_accuracy: 0.8000
# Epoch 49/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7690 - accuracy: 0.7486 - val_loss: 0.6384 - val_accuracy: 0.8133
# Epoch 50/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8050 - accuracy: 0.7257 - val_loss: 0.4955 - val_accuracy: 0.8267
# Epoch 51/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6345 - accuracy: 0.7600 - val_loss: 0.5766 - val_accuracy: 0.8267
# Epoch 52/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6296 - accuracy: 0.7771 - val_loss: 0.6102 - val_accuracy: 0.7733
# Epoch 53/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5278 - accuracy: 0.7543 - val_loss: 0.5843 - val_accuracy: 0.8400
# Epoch 54/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6609 - accuracy: 0.7543 - val_loss: 0.5075 - val_accuracy: 0.8267
# Epoch 55/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6163 - accuracy: 0.7714 - val_loss: 0.9990 - val_accuracy: 0.6933
# Epoch 56/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6062 - accuracy: 0.7829 - val_loss: 0.7666 - val_accuracy: 0.8000
# Epoch 57/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6795 - accuracy: 0.7486 - val_loss: 0.7750 - val_accuracy: 0.7467
# Epoch 58/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6738 - accuracy: 0.7657 - val_loss: 0.5524 - val_accuracy: 0.8267
# Epoch 59/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6894 - accuracy: 0.7200 - val_loss: 0.4638 - val_accuracy: 0.8267
# Epoch 60/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.6034 - accuracy: 0.7812
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6407 - accuracy: 0.7600 - val_loss: 0.4785 - val_accuracy: 0.8400
# Epoch 61/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5017 - accuracy: 0.8114 - val_loss: 0.5388 - val_accuracy: 0.8400
# Epoch 62/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4932 - accuracy: 0.7657 - val_loss: 0.4879 - val_accuracy: 0.8533
# Epoch 63/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4377 - accuracy: 0.7771 - val_loss: 0.5336 - val_accuracy: 0.8267
# Epoch 64/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5234 - accuracy: 0.7886 - val_loss: 0.4826 - val_accuracy: 0.8000
# Epoch 65/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4594 - accuracy: 0.7943 - val_loss: 0.4865 - val_accuracy: 0.8400
# Epoch 66/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4943 - accuracy: 0.8171 - val_loss: 0.9117 - val_accuracy: 0.6933
# Epoch 67/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7472 - accuracy: 0.7314 - val_loss: 0.4022 - val_accuracy: 0.7867
# Epoch 68/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5014 - accuracy: 0.8171 - val_loss: 0.4835 - val_accuracy: 0.8000
# Epoch 69/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.5134 - accuracy: 0.8000
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5277 - accuracy: 0.8000 - val_loss: 0.6609 - val_accuracy: 0.7467
# Epoch 70/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5313 - accuracy: 0.7886 - val_loss: 0.3779 - val_accuracy: 0.8267
# Epoch 71/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4761 - accuracy: 0.8057 - val_loss: 0.3472 - val_accuracy: 0.8400
# Epoch 72/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4329 - accuracy: 0.8286 - val_loss: 0.3476 - val_accuracy: 0.8533
# Epoch 73/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4032 - accuracy: 0.8229 - val_loss: 0.5393 - val_accuracy: 0.8267
# Epoch 74/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4243 - accuracy: 0.8171 - val_loss: 0.4323 - val_accuracy: 0.8533
# Epoch 75/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4115 - accuracy: 0.8400 - val_loss: 0.4808 - val_accuracy: 0.8533
# Epoch 76/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.3803 - accuracy: 0.8250
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3717 - accuracy: 0.8229 - val_loss: 0.4911 - val_accuracy: 0.8400
# Epoch 77/100
# 175/175 [==============================] - 1s 3ms/sample - loss: 0.4709 - accuracy: 0.8057 - val_loss: 0.4650 - val_accuracy: 0.8267
# Epoch 78/100
# 175/175 [==============================] - 0s 3ms/sample - loss: 0.3766 - accuracy: 0.8343 - val_loss: 0.4190 - val_accuracy: 0.8533
# Epoch 79/100
# 175/175 [==============================] - 0s 3ms/sample - loss: 0.4260 - accuracy: 0.8343 - val_loss: 0.4829 - val_accuracy: 0.8533
# Epoch 80/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3203 - accuracy: 0.8686 - val_loss: 0.5117 - val_accuracy: 0.8267
# Epoch 81/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4680 - accuracy: 0.7886 - val_loss: 0.4095 - val_accuracy: 0.8400
# Epoch 82/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3304 - accuracy: 0.8571 - val_loss: 0.4103 - val_accuracy: 0.8267
# Epoch 83/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.3150 - accuracy: 0.8750
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3187 - accuracy: 0.8800 - val_loss: 0.4014 - val_accuracy: 0.8533
# Epoch 84/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4066 - accuracy: 0.8457 - val_loss: 0.3337 - val_accuracy: 0.8533
# Epoch 85/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3410 - accuracy: 0.8629 - val_loss: 0.3489 - val_accuracy: 0.8533
# Epoch 86/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4186 - accuracy: 0.8229 - val_loss: 0.4392 - val_accuracy: 0.8400
# Epoch 87/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4378 - accuracy: 0.8229 - val_loss: 0.4558 - val_accuracy: 0.8533
# Epoch 88/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3910 - accuracy: 0.8457 - val_loss: 0.4880 - val_accuracy: 0.8667
# Epoch 89/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4393 - accuracy: 0.8457 - val_loss: 0.3996 - val_accuracy: 0.8533
# Epoch 90/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3364 - accuracy: 0.8629 - val_loss: 0.4623 - val_accuracy: 0.8400
# Epoch 91/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4000 - accuracy: 0.8686 - val_loss: 0.4839 - val_accuracy: 0.8533
# Epoch 92/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5059 - accuracy: 0.7886 - val_loss: 0.3589 - val_accuracy: 0.8267
# Epoch 93/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3578 - accuracy: 0.8686 - val_loss: 0.4413 - val_accuracy: 0.8267
# Epoch 94/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4937 - accuracy: 0.8229 - val_loss: 0.5276 - val_accuracy: 0.8400
# Epoch 95/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3536 - accuracy: 0.8686 - val_loss: 0.5306 - val_accuracy: 0.8800
# Epoch 96/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3147 - accuracy: 0.8800 - val_loss: 0.5467 - val_accuracy: 0.8400
# Epoch 97/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3151 - accuracy: 0.8800 - val_loss: 0.5443 - val_accuracy: 0.8667
# Epoch 98/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3547 - accuracy: 0.8686 - val_loss: 0.5225 - val_accuracy: 0.8400
# Epoch 99/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3238 - accuracy: 0.8629 - val_loss: 0.6039 - val_accuracy: 0.8400
# Epoch 100/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3798 - accuracy: 0.8686 - val_loss: 0.5750 - val_accuracy: 0.8400

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.savefig('epoch_history.png')
pyplot.show()

# %% [markdown]
# `The fluctuations in the epoch metrics is due to the fact that we have very low data for such a complex task.`

# %%
yhat_valid = model.predict_classes(X_valid)
scikitplot.metrics.plot_confusion_matrix(np.argmax(y_valid, axis=1), yhat_valid, figsize=(7,7))
pyplot.savefig("confusion_matrix.png")

print(f'total wrong validation predictions: {np.sum(np.argmax(y_valid, axis=1) != yhat_valid)}\n\n')
print(classification_report(np.argmax(y_valid, axis=1), yhat_valid))
# Out:
# total wrong validation predictions: 12
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.91      1.00      0.95        21
#            2       0.61      0.85      0.71        13
#            3       1.00      0.12      0.22         8
#            4       0.67      0.75      0.71         8
#
#     accuracy                           0.84        75
#    macro avg       0.84      0.74      0.71        75
# weighted avg       0.87      0.84      0.82        75

# %% [markdown]
# `If we have more data to train then we will get better and more generalized model.`

# %%
np.random.seed(0)
indices = np.random.choice(range(X_valid.shape[0]), size=15, replace=False)

fig = pyplot.figure(1, (9,30))

i = 0
for idx in indices:
    true_emotion = label_emotion_mapper[np.argmax(y_valid[idx])]
    pred_emotion = label_emotion_mapper[model.predict_classes(np.expand_dims(X_valid[idx], axis=0))[0]]
    
    for j in range(3):
        i += 1
        ax = pyplot.subplot(15,3,i)
        sample_img = X_valid[idx,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:{true_emotion}, p:{pred_emotion}")
